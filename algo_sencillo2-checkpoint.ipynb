# %%
#Librerias para la regresion lineal
import pandas as pd
import numpy as np
from pylab import rcParams
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
from collections import Counter

# %%
# %matplotlib inline
rcParams["figure.figsize"]=5, 4
sns.set_style("whitegrid")

# %%
data= pd.read_csv("label_market_hn.csv")

# %%
correlacion= data.corr()

# %%
correlacion_df=pd.DataFrame(correlacion)

print data.corr()
# Out:
#                                              Time  Total employment_T  \
# Time                                     1.000000            0.989188
# Total employment_T                       0.989188            1.000000
#  Employees_T                             0.956102            0.971995
# Employers_T                              0.907665            0.893766
# Own account workers_T                   -0.773813           -0.810416
# Contributing family workers_T            0.853650            0.863497
# Total_F                                 -0.841244           -0.843324
# Employees_F                              0.955447            0.971271
# Employers_F                              0.956706            0.970128
# Own account workers_F                    0.937171            0.970793
# Contributing family workers_F            0.898308            0.945238
# Total_M                                  0.997173            0.996705
# ...

# %%
df= pd.DataFrame(data)

df.head()
# Out:
#    Time  Total employment_T   Employees_T  Employers_T  Own account workers_T  \
# 0  2000               2.383         1.115          275                  750.0
# 1  2001               2.425         1.138          279                  765.0
# 2  2002               2.495         1.175          287                  785.0
# 3  2003               2.532         1.199          292                  794.0
# 4  2004               2.586         1.230          300                  810.0
#
#    Contributing family workers_T  Total_F  Employees_F  Employers_F  \
# 0                            243    827.0          367           37
# 1                            245    830.0          368           36
# 2                            248    848.0          378           37
# 3                            247    856.0          383           38
# 4                            246    865.0          389           38
#
#    Own account workers_F  ...  Total employment_F  Informal emloyment_F  \
# ...

# %%
g1= sns.regplot(data=df, x="Employers_T", y="Total employment_T")

# %%
g2= sns.regplot(data=df, x="Own account workers_T", y="Total employment_T")

# %%
g3= sns.regplot(data=df, x="Contributing family workers_T",  y="Total employment_T")

# %%
g4= sns.regplot(data=df, x="Total_F", y="Total employment_T")

# %%
g5= sns.regplot(data=df, x="Employers_F", y="Total employment_T")

# %%
g6= sns.regplot(data=df, x="Own account workers_F", y="Total employment_T")

# %%
g7= sns.regplot(data=df, x="Contributing family workers_F", y="Total employment_T")

# %%
g8= sns.regplot(data=df, x="Total_M", y="Total employment_T")

# %%
g9= sns.regplot(data=df, x="Employees_M", y="Total employment_T")

# %%
g10= sns.regplot(data=df, x="Employers_M", y="Total employment_T")

# %%
g12= sns.regplot(data=df, x="Contributing family workers_M", y="Total employment_T")

# %%
g13= sns.regplot(data=df, x="Informal emloyment_T", y="Total employment_T")

# %%
g14= sns.regplot(data=df, x="Formal employment_T", y="Total employment_T")

# %%
g15= sns.regplot(data=df, x="Employment outside the formal sector_T", y="Total employment_T")
