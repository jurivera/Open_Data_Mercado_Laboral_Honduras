# %%
import pandas as pd
import numpy as np

# %%
a=1+1

# %%
a
# Out:
# 2

# %%
data = pd.read_csv("label_market_hn.csv")

# %%
print (data)
print
# Out:
#     Time  Total employment_T   Employees_T  Employers_T  \
# 0   2000               2.383         1.115          275
# 1   2001               2.425         1.138          279
# 2   2002               2.495         1.175          287
# 3   2003               2.532         1.199          292
# 4   2004               2.586         1.230          300
# 5   2005               2.690         1.287          312
# 6   2006               2.747         1.322          327
# 7   2007               2.804         1.383          386
# 8   2008               2.932         1.453          373
# 9   2009               3.076         1.459          387
# 10  2010               3.204         1.431          424
# 11  2011               3.182         1.502          355
# 12  2012               3.255         1.406          378
# 13  2013               3.495         1.548          448
# 14  2014               3.623         1.796          416
# 15  2015               3.764         1.822          365
# 16  2016               3.821         1.974          421
# 17  2017               3.962         1.884          460
# 18  2018               4.063         1.944          472
#
#     Own account workers_T  Contributing family workers_T  Total_F  \
# 0                 750.000                            243  827.000
# 1                 765.000                            245  830.000
# 2                 785.000                            248  848.000
# 3                 794.000                            247  856.000
# 4                 810.000                            246  865.000
# 5                 841.000                            250  909.000
# 6                 855.000                            243  895.000
# 7                 813.000                            222  908.000
# 8                 872.000                            235  987.000
# 9                 967.000                            263    1.050
# 10                  1.024                            324    1.111
# 11                977.000                            348    1.059
# 12                  1.131                            340    1.075
# 13                  1.174                            325    1.206
# 14                  1.111                            301    1.291
# 15                  1.213                            363    1.344
# 16                  1.096                            329    1.375
# 17                  1.266                            353    1.427
# 18                  1.294                            354    1.471
#
#     Employees_F  Employers_F  Own account workers_F  ...  Total employment_F  \
# 0           367           37                    342  ...                 NaN
# 1           368           36                    344  ...                 NaN
# 2           378           37                    351  ...                 NaN
# 3           383           38                    354  ...                 NaN
# 4           389           38                    358  ...                 NaN
# 5           411           41                    375  ...                 NaN
# 6           421           43                    362  ...             904.000
# 7           433           45                    354  ...             918.000
# 8           472           52                    388  ...               1.010
# 9           447           56                    450  ...               1.070
# 10          465           58                    470  ...               1.129
# 11          490           51                    403  ...               1.088
# 12          459           62                    452  ...               1.086
# 13          494           64                    522  ...               1.231
# 14          580           70                    509  ...               1.271
# 15          583           61                    546  ...               1.346
# 16          629           81                    519  ...               1.370
# 17          591           81                    597  ...               1.396
# 18          614           84                    613  ...                 NaN
#
#     Informal emloyment_F  Formal employment_F  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                619.000                286.0
# 7                607.000                310.0
# 8                752.000                258.0
# 9                800.000                269.0
# 10               868.000                261.0
# 11               843.000                244.0
# 12               868.000                217.0
# 13               983.000                248.0
# 14               993.000                278.0
# 15                 1.060                286.0
# 16                 1.081                290.0
# 17                 1.069                327.0
# 18                   NaN                  NaN
#
#     Employment outside the formal sector__F  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                   604.000
# 7                                   588.000
# 8                                   718.000
# 9                                   778.000
# 10                                  846.000
# 11                                  809.000
# 12                                  836.000
# 13                                  955.000
# 14                                  954.000
# 15                                    1.027
# 16                                    1.030
# 17                                    1.018
# 18                                      NaN
#
#     Employment in the formal sector_F  Total employment_M  \
# 0                                 NaN                 NaN
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
# 5                                 NaN                 NaN
# 6                               300.0               1.682
# 7                               330.0               1.727
# 8                               292.0               1.825
# 9                               292.0               1.905
# 10                              283.0               1.978
# 11                              279.0               2.008
# 12                              250.0               2.031
# 13                              276.0               2.110
# 14                              317.0               2.043
# 15                              319.0               2.130
# 16                              340.0               2.144
# 17                              378.0               2.271
# 18                                NaN                 NaN
#
#     Informal emloyment_M  Formal employment_M  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                  1.304                378.0
# 7                  1.302                425.0
# 8                  1.498                327.0
# 9                  1.543                362.0
# 10                 1.628                350.0
# 11                 1.693                316.0
# 12                 1.741                290.0
# 13                 1.782                328.0
# 14                 1.671                372.0
# 15                 1.749                381.0
# 16                 1.742                402.0
# 17                 1.837                434.0
# 18                   NaN                  NaN
#
#     Employment outside the formal sector_M  Employment in the formal sector_M
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# 5                                      NaN                                NaN
# 6                                    1.286                              397.0
# 7                                    1.281                              446.0
# 8                                    1.472                              353.0
# 9                                    1.527                              378.0
# 10                                   1.609                              369.0
# 11                                   1.667                              342.0
# 12                                   1.713                              318.0
# 13                                   1.757                              353.0
# 14                                   1.647                              396.0
# 15                                   1.718                              412.0
# 16                                   1.701                              443.0
# 17                                   1.809                              462.0
# 18                                     NaN                                NaN
#
# [19 rows x 30 columns]

# %%
x = data.iloc[:,:16]
y= data.iloc[:,1]

# %%
data.head()
# Out:
#    Time  Total employment_T   Employees_T  Employers_T  Own account workers_T  \
# 0  2000               2.383         1.115          275                  750.0
# 1  2001               2.425         1.138          279                  765.0
# 2  2002               2.495         1.175          287                  785.0
# 3  2003               2.532         1.199          292                  794.0
# 4  2004               2.586         1.230          300                  810.0
#
#    Contributing family workers_T  Total_F  Employees_F  Employers_F  \
# 0                            243    827.0          367           37
# 1                            245    830.0          368           36
# 2                            248    848.0          378           37
# 3                            247    856.0          383           38
# 4                            246    865.0          389           38
#
#    Own account workers_F  ...  Total employment_F  Informal emloyment_F  \
# 0                    342  ...                 NaN                   NaN
# 1                    344  ...                 NaN                   NaN
# 2                    351  ...                 NaN                   NaN
# 3                    354  ...                 NaN                   NaN
# 4                    358  ...                 NaN                   NaN
#
#    Formal employment_F  Employment outside the formal sector__F  \
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
#
#    Employment in the formal sector_F  Total employment_M  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
#
#    Informal emloyment_M  Formal employment_M  \
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
#
#    Employment outside the formal sector_M  Employment in the formal sector_M
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
#
# [5 rows x 30 columns]

# %%
x= data.iloc[:,:16]
y= data.iloc[:,1]

# %%
x.head()
# Out:
#    Time  Total employment_T   Employees_T  Employers_T  Own account workers_T  \
# 0  2000               2.383         1.115          275                  750.0
# 1  2001               2.425         1.138          279                  765.0
# 2  2002               2.495         1.175          287                  785.0
# 3  2003               2.532         1.199          292                  794.0
# 4  2004               2.586         1.230          300                  810.0
#
#    Contributing family workers_T  Total_F  Employees_F  Employers_F  \
# 0                            243    827.0          367           37
# 1                            245    830.0          368           36
# 2                            248    848.0          378           37
# 3                            247    856.0          383           38
# 4                            246    865.0          389           38
#
#    Own account workers_F  Contributing family workers_F  Total_M  Employees_M  \
# 0                    342                             82    1.556        749.0
# 1                    344                             81    1.595        769.0
# 2                    351                             82    1.647        797.0
# 3                    354                             81    1.676        815.0
# 4                    358                             80    1.721        841.0
#
#    Employers_M  Own account workers_M  Contributing family workers_M
# 0          238                    408                            162
# 1          242                    420                            163
# 2          250                    434                            166
# 3          255                    440                            166
# 4          261                    452                            166

# %%
y.head()
# Out:
# 0    2.383
# 1    2.425
# 2    2.495
# 3    2.532
# 4    2.586
# Name: Total employment_T, dtype: float64

# %%
x= data.iloc[:,:16]
y= data.iloc[:,1]

# %%
y.head()
# Out:
# 0    2.383
# 1    2.425
# 2    2.495
# 3    2.532
# 4    2.586
# Name: Total employment_T, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
x.shape
# Out:
# (19, 16)

# %%
eje_x= list(range(x.shape(0)))
eje_y= y

fig, ax= plt.subplots()
ax.plot (eje_x, eje_y,"-")
fig.set_size_inches(15,7)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-12d6fc3c482c> in <module>()
# ----> 1 eje_x= list(range(x.shape(0)))
#       2 eje_y= y
#       3
#       4 fig, ax= plt.subplots()
#       5 ax.plot (eje_x, eje_y,"-")
#
# TypeError: 'tuple' object is not callable

# %%
eje_x= list(range(x.shape[0]))
eje_y= y

fig, ax= plt.subplots()
ax.plot (eje_x, eje_y,"-")
fig.set_size_inches(10,5)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import seaborn as sns

# %%
sns.set(style="ticks")
sns.pairplot(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.7, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred= model.predict(x_test)

# %%
y_pred
# Out:
# array([2.55872197, 2.96140385, 2.78363485, 3.24446944, 2.52659093,
#        2.95725955, 2.60869282, 3.02835104, 2.86814494, 2.46604081,
#        2.95951455, 2.42921826, 3.22288568, 3.15281794])

# %%
comp= pd.DataFrame({"real" : y_test, "pred" :y_pred})

# %%
comp.head()
# Out:
#         pred   real
# 3   2.558722  2.532
# 15  2.961404  3.764
# 6   2.783635  2.747
# 10  3.244469  3.204
# 2   2.526591  2.495

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE= mean_squared_error(y_test, y_pred)

# %%
MSE
# Out:
# 0.24115125644241991

# %%
eje_x= list(range(x_test.shape[0]))
eje_y= y_test
eje_y2= y_pred

fig, ax= plt.subplots()
ax.plot(eje_x, eje_y, "-", eje_x, eje_y2, "o")
fig.set_size_inches(10,5)
